# %% [markdown]
# # Different Text Similarities Method on Linkedin Data

# %% [markdown]
# ## Pre-requisite

# %% [markdown]
# ### Import Libraries

# %%
# !pip install pandas
# !pip install nltk
# !pip install beautifulsoup4
# !pip install -U scikit-learn
# !pip install heatmapz

# %%
import pandas as pd
import nltk
from bs4 import BeautifulSoup
import string
import re
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer
from nltk.stem import WordNetLemmatizer
from nltk.stem.porter import PorterStemmer
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Justi\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\Justi\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
df["Training"][0]
letters_only_text = re.sub("[^a-zA-Z]", " ", df["Training"][0])
letters_only_text
words = letters_only_text.lower().split()
words = ['software', 'engineering', 'intern', 'in', 'd', 'ford', 'palo', 'alto', 'ca', 'forbes', 'under', 'scholar', 'machine', 'learning', 'researcher', 'palo', 'alto', 'california', 'united', 'states', 'hello', 'world', 'i', 'am']
stopword_set = set(stopwords.words("english"))
cleaned_words = list(set([w for w in words if w not in stopword_set]))
cleaned_words
cleaned_words2 = word_lemmatizer(cleaned_words)
cleaned_words2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-227d3c0683bc> in <module>
# ----> 1 df["Training"][0]
#       2 letters_only_text = re.sub("[^a-zA-Z]", " ", df["Training"][0])
#       3 letters_only_text
#       4 words = letters_only_text.lower().split()
#       5 words = ['software', 'engineering', 'intern', 'in', 'd', 'ford', 'palo', 'alto', 'ca', 'forbes', 'under', 'scholar', 'machine', 'learning', 'researcher', 'palo', 'alto', 'california', 'united', 'states', 'hello', 'world', 'i', 'am']
#
# NameError: name 'df' is not defined

# %%
Software Engineering Intern in D-Ford Palo Alto, CA | Forbes 30 Under 30 Scholar | Machine Learning Researcher Palo Alto, California, United States hello, world!\nI am


Software Engineering Intern in D Ford Palo Alto  CA   Forbes    Under    Scholar   Machine Learning Researcher Palo Alto  California  United States hello  world  I am

['software', 'engineering', 'intern', 'in', 'd', 'ford', 'palo', 'alto', 'ca', 'forbes', 'under', 'scholar', 'machine', 'learning', 'researcher', 'palo', 'alto', 'california', 'united', 'states', 'hello', 'world', 'i', 'am']

['engineering', 'learning', 'california', 'ford', 'alto', 'scholar', 'hello', 'world', 'forbes', 'states', 'software', 'palo', 'ca', 'united', 'intern', 'researcher', 'machine']

'engineering learning california ford alto scholar hello world forbes state software palo ca united intern researcher machine'

# %% [markdown]
# ### Load & Preprocess Data

# %%
df = pd.read_csv('results_profiles_1594604185.csv')
df = df[df.Name != 'John D.']
df.dropna(axis=1,how='all')
df.shape
df

training = df.apply(lambda row: row["Headline"] + " " + row["Location"] + " " + row["Desc"] + " " + row["Skills"], axis = 1)
df['Training'] = training

# %%
def preprocess(raw_text):

    # keep only words
    letters_only_text = re.sub("[^a-zA-Z]", " ", raw_text)

    # convert to lower case and split 
    words = letters_only_text.lower().split()

    # remove stopwords
    stopword_set = set(stopwords.words("english"))
    cleaned_words = list(set([w for w in words if w not in stopword_set]))

    return cleaned_words

### Only for bag of words Cosine Similarity

## Instantiate lemmatizer
lemmatizer = WordNetLemmatizer()

def word_lemmatizer(text):
    lem_text = " ".join([lemmatizer.lemmatize(i) for i in text])
    return lem_text

stemmer = PorterStemmer()

def word_stemmer(text):
    stem_text = " ".join([stemmer.stem(i) for i in text])
    return stem_text

# %% [markdown]
# ## Method 1: Cosine Similarity Matrix

# %%
df_m1 = df.copy()
df_m1['Training'] = df_m1['Training'].apply(lambda x: preprocess(x))
df_m1['Training'] = df_m1['Training'].apply(lambda x: word_lemmatizer(x))
df_m1['Training']
# Out:
# 0     commerce could computer michigan havard dashbo...
# 1     michigan intro service entry networking arduin...
# 2     good computer language office software service...
# 3     united engineering computer working honolulu e...
# 4     ip computer o tensorflow swift r software area...
# 5     uc machine computer area interest vision berke...
# 6     motivated associated teaming entrepreneurial d...
# 7     begun studio accolade tableau service watson c...
# 8     city creative stavros organizing metropolitan ...
# 9     united good language software aspire angularjs...
# 10    orcad microwave studio grateful help future ex...
# 11    partnership corporate company finance startup ...
# 13    language uikit working o xcode currently swift...
# Name: Training, dtype: object

# %%
df_m1['Training']
# Out:
# 0     commerce could computer michigan havard dashbo...
# 1     michigan intro service entry networking arduin...
# 2     good computer language office software service...
# 3     united engineering computer working honolulu e...
# 4     ip computer o tensorflow swift r software area...
# 5     uc machine computer area interest vision berke...
# 6     motivated associated teaming entrepreneurial d...
# 7     begun studio accolade tableau service watson c...
# 8     city creative stavros organizing metropolitan ...
# 9     united good language software aspire angularjs...
# 10    orcad microwave studio grateful help future ex...
# 11    partnership corporate company finance startup ...
# 13    language uikit working o xcode currently swift...
# Name: Training, dtype: object

# %%
# Scikit Learn
from sklearn.feature_extraction.text import CountVectorizer
import pandas as pd
from sklearn.metrics.pairwise import cosine_similarity
from scipy.spatial import distance

# Create the Document Term Matrix
count_vectorizer = CountVectorizer(stop_words='english')
count_vectorizer = CountVectorizer()
sparse_matrix = count_vectorizer.fit_transform(df_m1['Training'])

# OPTIONAL: Convert Sparse Matrix to Pandas Dataframe if you want to see the word frequencies.
doc_term_matrix = sparse_matrix.todense()
df_cosine = pd.DataFrame(doc_term_matrix, 
                  columns=count_vectorizer.get_feature_names(), 
                  index=df_m1['Name'])
df_cosine
# Out:
#                              ability  able  academic  access  accolade  \
# Name
# Justin Lee                         1     0         0       0         0
# Zhi Yan (Ian) Leong [龙智彦] 😎        0     0         0       0         0
# Noah Cook                          0     1         0       0         0
# Daniel Ramsey                      0     0         0       0         0
# Jia Guo                            0     0         0       0         0
# Mokshith Voodarla                  0     0         0       0         0
# Xianyi “Sen” Xiong                 0     0         1       0         0
# Daniela Beck                       0     0         1       1         1
# Stavros Anastasiou                 0     0         0       0         0
# Victoria Johnson                   0     0         0       0         0
# M. Razlan Dhamir Hamdan            0     0         0       0         0
# Dzuleira Abu Bakar                 0     0         0       0         0
# Andrew Nguyen                     0     0         0       0         0
#
#                              accounting  achieve  across  act  acting  ...  \
# Name                                                                   ...
# Justin Lee                            0        0       0    0       0  ...
# Zhi Yan (Ian) Leong [龙智彦] 😎           0        1       0    0       0  ...
# Noah Cook                             0        0       0    0       0  ...
# Daniel Ramsey                         0        0       0    0       0  ...
# Jia Guo                               0        0       0    0       0  ...
# Mokshith Voodarla                     0        0       0    0       0  ...
# Xianyi “Sen” Xiong                    0        0       0    1       0  ...
# Daniela Beck                          1        0       1    0       0  ...
# Stavros Anastasiou                    1        0       0    0       0  ...
# Victoria Johnson                      0        0       0    0       0  ...
# M. Razlan Dhamir Hamdan               0        0       0    0       1  ...
# Dzuleira Abu Bakar                    0        0       0    0       0  ...
# Andrew Nguyen                        0        0       0    0       0  ...
#
#                              work  working  world  writer  writing  xcode  \
# Name
# Justin Lee                      1        0      1       0        0      0
# Zhi Yan (Ian) Leong [龙智彦] 😎     1        0      1       0        0      0
# Noah Cook                       0        0      0       0        0      0
# Daniel Ramsey                   0        1      0       0        0      0
# Jia Guo                         0        0      0       0        0      0
# Mokshith Voodarla               0        0      0       0        0      0
# Xianyi “Sen” Xiong              0        0      0       0        0      0
# Daniela Beck                    1        0      0       0        0      0
# Stavros Anastasiou              0        1      0       1        1      0
# Victoria Johnson                0        0      0       0        0      0
# M. Razlan Dhamir Hamdan         0        0      1       0        0      0
# Dzuleira Abu Bakar              0        0      0       0        0      0
# Andrew Nguyen                  0        1      0       0        0      1
#
#                              xml  york  young  youth
# Name
# Justin Lee                     0     0      0      0
# Zhi Yan (Ian) Leong [龙智彦] 😎    0     0      0      0
# Noah Cook                      0     0      0      0
# Daniel Ramsey                  0     0      0      0
# Jia Guo                        0     0      0      0
# Mokshith Voodarla              0     0      0      0
# Xianyi “Sen” Xiong             0     0      0      0
# Daniela Beck                   1     0      1      0
# Stavros Anastasiou             0     1      0      0
# Victoria Johnson               0     1      0      0
# M. Razlan Dhamir Hamdan        0     0      0      1
# Dzuleira Abu Bakar             0     0      0      0
# Andrew Nguyen                 0     0      0      0
#
# [13 rows x 662 columns]

# %%
df_test = pd.DataFrame([["Time is very slow for those who wait"],["Very fast for those who are scared"]], columns =['sent'])
df_test = df_test['sent'].apply(lambda x: preprocess(x))
df_test = df_test['sent'].apply(lambda x: word_lemmatizer(x))
df_test
# Out:
#                                    sent
# 0  Time is very slow for those who wait
# 1    Very fast for those who are scared

# %%
#Comparing Noah with Victoria "As benchmark"
cosine = distance.cosine(sparse_matrix.toarray()[2].tolist(), sparse_matrix.toarray()[9].tolist())
print('Similarity of two sentences are equal to ',round((1-cosine)*100,2),'%')
# Out:
# Similarity of two sentences are equal to  45.07 %

# %%
## Changing Name for privacy Issues

df_cosine.index
df_cosine_placeholder = ['Justin', 'John', 'Albert',
       'Nick', 'Jason', 'Kevin', 'Steve',
       'Amy', 'Victoria', 'Sarah',
       'Nancy', 'Tyler', 'Andy']

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from heatmap import heatmap, corrplot
import numpy as np

#corr = np.subtract(cosine_similarity(df_cosine, df_cosine),1)
corr = cosine_similarity(df_cosine, df_cosine)
plt.figure(figsize=(8, 8))
ax = sns.heatmap(
    corr, 
    vmin= 0, vmax=1, center=0,
    cmap=sns.diverging_palette(220, 20, n=200),
    square=True
)

ax.set_xticklabels(
    df_cosine_placeholder,
    rotation=45,
    horizontalalignment='right'
);

ax.set_yticklabels(
    df_cosine_placeholder,
    rotation=0,
    horizontalalignment='right'
);

# %%
corr
# Out:
# array([[1.        , 0.12941703, 0.25928149, 0.14113497, 0.24647955,
#         0.22547802, 0.07524103, 0.20099944, 0.080016  , 0.21573524,
#         0.15671662, 0.04989875, 0.11004875],
#        [0.12941703, 1.        , 0.17616607, 0.09589266, 0.11696173,
#         0.14855627, 0.11076372, 0.13110427, 0.10873206, 0.13029247,
#         0.15431805, 0.02260212, 0.11393746],
#        [0.25928149, 0.17616607, 1.        , 0.17010345, 0.22633937,
#         0.15811388, 0.07254763, 0.1860521 , 0.03857584, 0.45069391,
#         0.07883825, 0.        , 0.12126781],
#        [0.14113497, 0.09589266, 0.17010345, 1.        , 0.14784425,
#         0.12909944, 0.05923489, 0.05063697, 0.14698618, 0.18871284,
#         0.05721881, 0.02618914, 0.09901475],
#        [0.24647955, 0.11696173, 0.22633937, 0.14784425, 1.        ,
#         0.25766925, 0.10509045, 0.16844366, 0.06984984, 0.17577069,
#         0.10468597, 0.        , 0.24153958],
#        [0.22547802, 0.14855627, 0.15811388, 0.12909944, 0.25766925,
#         1.        , 0.06882472, 0.11766968, 0.048795  , 0.0438529 ,
#         0.09972337, 0.        , 0.19174125],
#        [0.07524103, 0.11076372, 0.07254763, 0.05923489, 0.10509045,
#         0.06882472, 1.        , 0.17996851, 0.14552644, 0.04024218,
#         0.09913848, 0.05584719, 0.07038153],
#        [0.20099944, 0.13110427, 0.1860521 , 0.05063697, 0.16844366,
#         0.11766968, 0.17996851, 1.        , 0.09569488, 0.12040366,
#         0.13690154, 0.04774099, 0.12033137],
#        [0.080016  , 0.10873206, 0.03857584, 0.14698618, 0.06984984,
#         0.048795  , 0.14552644, 0.09569488, 1.        , 0.06419407,
#         0.08921004, 0.02969569, 0.07484812],
#        [0.21573524, 0.13029247, 0.45069391, 0.18871284, 0.17577069,
#         0.0438529 , 0.04024218, 0.12040366, 0.06419407, 1.        ,
#         0.11661758, 0.        , 0.13453456],
#        [0.15671662, 0.15431805, 0.07883825, 0.05721881, 0.10468597,
#         0.09972337, 0.09913848, 0.13690154, 0.08921004, 0.11661758,
#         1.        , 0.11126447, 0.06373695],
#        [0.04989875, 0.02260212, 0.        , 0.02618914, 0.        ,
#         0.        , 0.05584719, 0.04774099, 0.02969569, 0.        ,
#         0.11126447, 1.        , 0.023338  ],
#        [0.11004875, 0.11393746, 0.12126781, 0.09901475, 0.24153958,
#         0.19174125, 0.07038153, 0.12033137, 0.07484812, 0.13453456,
#         0.06373695, 0.023338  , 1.        ]])

# %% [markdown]
# # Method 2: Consine Similarity with GloVe

# %%
df_m2 = df.copy()
df_m2['Training'] = df_m2['Training'].apply(lambda x: preprocess(x))

# %%
df_m2
# Out:
#                            Name  \
# 0                    Justin Lee
# 1   Zhi Yan (Ian) Leong [龙智彦] 😎
# 2                     Noah Cook
# 3                 Daniel Ramsey
# 4                       Jia Guo
# 5             Mokshith Voodarla
# 6            Xianyi “Sen” Xiong
# 7                  Daniela Beck
# 8            Stavros Anastasiou
# 9              Victoria Johnson
# 10      M. Razlan Dhamir Hamdan
# 11           Dzuleira Abu Bakar
# 13              Andrew Nguyen 
#
#                                              Headline  \
# 0   Software Engineering Intern in D-Ford Palo Alt...
# 1   Future Me Laughing at My Current Profile | Ele...
# 2                  Software Engineer Intern at Google
# 3   Computer Engineering ‘20 | SWE intern @ Atlassian
# 4                         Software Engineer at Google
# 5       Computer Vision & Robotics | UC Berkeley EECS
# 6   Lifelong Student/Academic of Systems Microbiol...
# 7          PM + Analytics | Content Creator | Speaker
# 8   Writer at Greek Reporter l Queens College BA G...
# 9                  Software Engineer Intern at Google
# 10  Founder, CEO & Head of Engineering | Emerging ...
# 11  CEO at (MaGIC) Malaysian Global Innovation & C...
# 13                         Software Engineer at Apple
#
#                                 Location        Connection  \
# 0   Palo Alto, California, United States  500+ connections
# 1               Kalamazoo, Michigan Area  500+ connections
# 2                   Gainesville, Florida  500+ connections
# 3        Honolulu, Hawaii, United States  500+ connections
# 4                 San Francisco Bay Area   199 connections
# 5                 San Francisco Bay Area  500+ connections
# 6      Greater Minneapolis-St. Paul Area  500+ connections
# 7              Greater Pittsburgh Region  500+ connections
# 8        New York City Metropolitan Area   131 connections
# 9      New York, New York, United States    22 connections
# 10                  Greater Kuala Lumpur  500+ connections
# 11                              Malaysia  500+ connections
# 13                San Francisco Bay Area   407 connections
#
#                                                  Desc  \
# 0   hello, world!\nI am Justin Lee, a junior compu...
# 1   Live by the motto '💪Never say no until you try...
# 2   I'm Noah, a computer science student at the Un...
# 3   Experienced Teaching Assistant and Computer En...
# 4   Proficient in Python, Java, C/C++.\nFamiliar w...
# 5   I'm an EECS student at UC Berkeley with an int...
# 6   I aspire to create a synergy between human act...
# 7   Daniela is from Chatham University with a Bach...
# 8   Hello, my name is Stavros Anastasiou; I'm curr...
# 9   I love everything about the Internet, I aspire...
# 10  Leadership traits are the essence of everythin...
# 11  Venture capital & Tech Startup investments, pa...
# 13  I am currently a Software Engineer working on ...
#
#                          Email                   Phone     Birthday  \
# 0      justinlee38@outlook.com                     NaN          NaN
# 1            ianleong@live.com      269-2766449 (Home)       May 22
# 2         imnoahcook@gmail.com       3522143266 (Home)       May 21
# 3   danielramsey10@hotmail.com                     NaN          NaN
# 4            jia.guo@wmich.edu     2692677464 (Mobile)          NaN
# 5          mvoodarla@gmail.com                     NaN          NaN
# 6      xianyixiong01@gmail.com                     NaN          NaN
# 7     beck.a.daniela@gmail.com   724-493-3374 (Mobile)          NaN
# 8   stavroanastasiou@gmail.com                     NaN          NaN
# 9                          NaN                     NaN          NaN
# 10     mrazld.hamdan@gmail.com  +60 162420125 (Mobile)  November 19
# 11                         NaN                     NaN          NaN
# 13                         NaN                     NaN   October 12
#
#      ConnectedDate                                             Skills  ...  \
# 0              NaN  Machine Learning,Python (Programming Language)...  ...
# 1   March 29, 2019  Leadership,Lifelong Learning,Critical Thinking...  ...
# 2     June 5, 2020  C++,Java,Python (Programming Language),JavaScr...  ...
# 3    June 22, 2019   Python,C++,Golang,Management,Leadership,Training  ...
# 4   April 10, 2019  Java,C,Swift,iOS Development,Data Analysis,Alg...  ...
# 5   April 12, 2020  Machine Learning,Deep Learning,Android Develop...  ...
# 6    June 17, 2019  Leadership,Public Speaking,Research,Epidemiolo...  ...
# 7    June 17, 2019  Leadership,Project Management,Python,Financial...  ...
# 8    July 11, 2020  Project Management,Interpersonal Communication...  ...
# 9     July 7, 2020  JavaScript,PHP,Python (Programming Language),A...  ...
# 10   July 31, 2018  Microsoft Office,Leadership,Teamwork,Product D...  ...
# 11             NaN  Venture Capital,Corporate Finance,Due Diligenc...  ...
# 13             NaN  iOS,Objective-C,Swift,Agile Methodologies,Scru...  ...
#
#                                                 Year0 EducationName1  \
# 0   Dates attended or expected graduation\n\n2018 ...            NaN
# 1   Dates attended or expected graduation\n\n2020 ...            NaN
# 2                                       Grade\nJunior            NaN
# 3   Dates attended or expected graduation\n\n2017 ...            NaN
# 4                                         Grade\n3.89            NaN
# 5   Dates attended or expected graduation\n\n2019 ...            NaN
# 6                                                 NaN            NaN
# 7                                     Grade\n3.96/4.0            NaN
# 8                                Grade\n3.81/4.00 GPA            NaN
# 9                                          Grade\n4.0            NaN
# 10  Dates attended or expected graduation\n\n2019 ...            NaN
# 11                                                NaN            NaN
# 13  Dates attended or expected graduation\n\n2010 ...            NaN
#
#    DegreeName1 Major1 Year1 EducationName2 DegreeName2 Major2 Year2  \
# 0          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 1          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 2          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 3          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 4          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 5          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 6          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 7          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 8          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 9          NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 10         NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 11         NaN    NaN   NaN            NaN         NaN    NaN   NaN
# 13         NaN    NaN   NaN            NaN         NaN    NaN   NaN
#
#                                              Training
# 0   [machine, websites, proficient, scholar, sql, ...
# 1   [racquetball, say, organization, signal, sigma...
# 2   [gainesville, building, c, python, florida, st...
# 3   [atlassian, honolulu, demonstrated, c, python,...
# 4   [c, python, research, proficient, json, public...
# 5   [machine, python, student, interest, leadershi...
# 6   [built, greater, earth, aspire, quorum, manage...
# 7   [scholar, sql, greater, troubleshooting, techn...
# 8   [aspiring, scholar, cuny, communication, secto...
# 9   [python, build, web, greater, love, good, prog...
# 10  [designer, brightest, explore, greater, practi...
# 11  [centre, investment, setting, project, busines...
# 13  [uikit, c, currently, working, networking, x, ...
#
# [13 rows x 39 columns]

# %%
gloveFile = "data\glove.6B.50d.txt"
import numpy as np
def loadGloveModel(gloveFile):
    print ("Loading Glove Model")
    with open(gloveFile, encoding="utf8" ) as f:
        content = f.readlines()
    model = {}
    for line in content:
        splitLine = line.split()
        word = splitLine[0]
        embedding = np.array([float(val) for val in splitLine[1:]])
        model[word] = embedding
    print ("Done.",len(model)," words loaded!")
    return model

def cosine_distance_between_two_words(word1, word2):
    import scipy
    return (1- scipy.spatial.distance.cosine(model[word1], model[word2]))

def calculate_heat_matrix_for_two_sentences(s1,s2):
    s1 = preprocess(s1)
    s2 = preprocess(s2)
    result_list = [[cosine_distance_between_two_words(word1, word2) for word2 in s2] for word1 in s1]
    result_df = pd.DataFrame(result_list)
    result_df.columns = s2
    result_df.index = s1
    return result_df

def cosine_distance_wordembedding_method(s1, s2):
    import scipy
#     for doc in df['Desc']:
#         words = filter(lambda x: x in model.vocab, doc)
    vector_1 = np.mean([model[word] for word in filter(lambda x: x in model, s1)],axis=0)
    vector_2 = np.mean([model[word] for word in filter(lambda x: x in model, s2)],axis=0)
    cosine = scipy.spatial.distance.cosine(vector_1, vector_2)
    similarity_value = round((1-cosine)*100,2)
#     print('Word Embedding method with a cosine distance asses that our two sentences are similar to',similarity_value,'%')
    return similarity_value

def heat_map_matrix_between_two_sentences(s1,s2):
    df = calculate_heat_matrix_for_two_sentences(s1,s2)
    import seaborn as sns
    import matplotlib.pyplot as plt
    fig, ax = plt.subplots(figsize=(5,5)) 
    ax_blue = sns.heatmap(df, cmap="YlGnBu")
    # ax_red = sns.heatmap(df)
    print(cosine_distance_wordembedding_method(s1, s2))
    return ax_blue

def calculate_heat_matrix_for_cosine_distance(a1,a2):
    desc1 = a1['Training'] 
    desc2 = a2['Training']
    result_list = [[cosine_distance_wordembedding_method(item1, item2) for item2 in desc2] for item1 in desc1]
    result_df = pd.DataFrame(result_list)
    result_df.columns = a2['Name']
    result_df.index = a1['Name']
    return result_df

def showing_in_heamap(result_df):
    plt.figure(figsize=(8, 8))
    ax = sns.heatmap(
        result_df.corr(), 
        vmin=0, vmax=1, center=0,
        cmap=sns.diverging_palette(220, 20, n=200),
        square=True
    )
    ax.set_xticklabels(
        # df_cosine.index,
        df_cosine_placeholder,
        rotation=45,
        horizontalalignment='right'
    );

    ax.set_yticklabels(
        #df_cosine.index,
        df_cosine_placeholder,
        rotation=0,
        horizontalalignment='right'
    );
    return ax

# %%
model = loadGloveModel(gloveFile)
# Out:
# Loading Glove Model
# Done. 400000  words loaded!

# %%
df2 = calculate_heat_matrix_for_cosine_distance(df_m2,df_m2)
df2
# Out:
# Name                         Justin Lee  Zhi Yan (Ian) Leong [龙智彦] 😎  \
# Name
# Justin Lee                       100.00                        96.99
# Zhi Yan (Ian) Leong [龙智彦] 😎       96.99                       100.00
# Noah Cook                         96.90                        92.35
# Daniel Ramsey                     90.65                        92.13
# Jia Guo                           88.77                        80.55
# Mokshith Voodarla                 93.93                        89.11
# Xianyi “Sen” Xiong                90.19                        89.38
# Daniela Beck                      96.96                        95.03
# Stavros Anastasiou                92.89                        94.57
# Victoria Johnson                  95.30                        90.81
# M. Razlan Dhamir Hamdan           95.63                        95.77
# Dzuleira Abu Bakar                80.66                        81.39
# Andrew Nguyen                    89.07                        81.13
#
# Name                         Noah Cook  Daniel Ramsey  Jia Guo  \
# Name
# Justin Lee                       96.90          90.65    88.77
# Zhi Yan (Ian) Leong [龙智彦] 😎      92.35          92.13    80.55
# Noah Cook                       100.00          88.87    89.99
# Daniel Ramsey                    88.87         100.00    72.74
# Jia Guo                          89.99          72.74   100.00
# Mokshith Voodarla                94.17          88.35    88.18
# Xianyi “Sen” Xiong               84.39          86.36    78.63
# Daniela Beck                     94.70          90.42    85.86
# Stavros Anastasiou               91.04          93.52    73.44
# Victoria Johnson                 96.77          83.08    91.66
# M. Razlan Dhamir Hamdan          90.53          88.02    83.34
# Dzuleira Abu Bakar               77.34          79.58    70.34
# Andrew Nguyen                   89.99          75.92    97.26
#
# Name                         Mokshith Voodarla  Xianyi “Sen” Xiong  \
# Name
# Justin Lee                               93.93               90.19
# Zhi Yan (Ian) Leong [龙智彦] 😎              89.11               89.38
# Noah Cook                                94.17               84.39
# Daniel Ramsey                            88.35               86.36
# Jia Guo                                  88.18               78.63
# Mokshith Voodarla                       100.00               84.82
# Xianyi “Sen” Xiong                       84.82              100.00
# Daniela Beck                             90.24               91.50
# Stavros Anastasiou                       88.14               88.30
# Victoria Johnson                         89.76               83.42
# M. Razlan Dhamir Hamdan                  87.29               92.46
# Dzuleira Abu Bakar                       75.34               82.87
# Andrew Nguyen                           88.36               78.85
#
# Name                         Daniela Beck  Stavros Anastasiou  \
# Name
# Justin Lee                          96.96               92.89
# Zhi Yan (Ian) Leong [龙智彦] 😎         95.03               94.57
# Noah Cook                           94.70               91.04
# Daniel Ramsey                       90.42               93.52
# Jia Guo                             85.86               73.44
# Mokshith Voodarla                   90.24               88.14
# Xianyi “Sen” Xiong                  91.50               88.30
# Daniela Beck                       100.00               94.97
# Stavros Anastasiou                  94.97              100.00
# Victoria Johnson                    94.64               87.04
# M. Razlan Dhamir Hamdan             95.38               90.72
# Dzuleira Abu Bakar                  86.76               80.73
# Andrew Nguyen                      86.40               75.29
#
# Name                         Victoria Johnson  M. Razlan Dhamir Hamdan  \
# Name
# Justin Lee                              95.30                    95.63
# Zhi Yan (Ian) Leong [龙智彦] 😎             90.81                    95.77
# Noah Cook                               96.77                    90.53
# Daniel Ramsey                           83.08                    88.02
# Jia Guo                                 91.66                    83.34
# Mokshith Voodarla                       89.76                    87.29
# Xianyi “Sen” Xiong                      83.42                    92.46
# Daniela Beck                            94.64                    95.38
# Stavros Anastasiou                      87.04                    90.72
# Victoria Johnson                       100.00                    91.99
# M. Razlan Dhamir Hamdan                 91.99                   100.00
# Dzuleira Abu Bakar                      79.14                    87.87
# Andrew Nguyen                          91.43                    85.12
#
# Name                         Dzuleira Abu Bakar  Andrew Nguyen 
# Name
# Justin Lee                                80.66            89.07
# Zhi Yan (Ian) Leong [龙智彦] 😎               81.39            81.13
# Noah Cook                                 77.34            89.99
# Daniel Ramsey                             79.58            75.92
# Jia Guo                                   70.34            97.26
# Mokshith Voodarla                         75.34            88.36
# Xianyi “Sen” Xiong                        82.87            78.85
# Daniela Beck                              86.76            86.40
# Stavros Anastasiou                        80.73            75.29
# Victoria Johnson                          79.14            91.43
# M. Razlan Dhamir Hamdan                   87.87            85.12
# Dzuleira Abu Bakar                       100.00            74.41
# Andrew Nguyen                            74.41           100.00

# %%
showing_in_heamap(df2)
# Out:
# <AxesSubplot:xlabel='Name', ylabel='Name'>

# %%
print(df_m2['Training'][2])
print(df_m2['Training'][3])
print(df_m2['Training'][9])
# Out:
# ['gainesville', 'building', 'c', 'python', 'florida', 'student', 'web', 'good', 'science', 'programming', 'use', 'graduate', 'forward', 'applications', 'java', 'language', 'internet', 'able', 'computer', 'customer', 'service', 'office', 'looking', 'engineer', 'software', 'passion', 'noah', 'university', 'javascript', 'put', 'intern', 'microsoft', 'google']
# ['atlassian', 'honolulu', 'demonstrated', 'c', 'python', 'training', 'leadership', 'swe', 'industry', 'working', 'education', 'history', 'science', 'golang', 'field', 'management', 'computer', 'assistant', 'engineer', 'united', 'experienced', 'engineering', 'states', 'higher', 'teaching', 'hawaii', 'skilled', 'intern']
# ['python', 'build', 'web', 'greater', 'love', 'good', 'programming', 'new', 'applications', 'aws', 'language', 'aspire', 'internet', 'everything', 'engineer', 'united', 'software', 'services', 'states', 'php', 'javascript', 'angularjs', 'york', 'amazon', 'intern', 'google']

# %%
model['python']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f0c844a8ef2a> in <module>
# ----> 1 model['python']
#
# NameError: name 'model' is not defined

# %% [markdown]
# ## Method 3: Word Embedding with FastText

# %%
df_m3 = df.copy()
df_m3['Training'] = df_m3['Training'].apply(lambda x: preprocess(x))

# %%
import io

def load_vectors(fname):
    fin = io.open(fname, 'r', encoding='utf-8', newline='\n', errors='ignore')
    n, d = map(int, fin.readline().split())
    data = {}
    for line in fin:
        tokens = line.rstrip().split(' ')
        data[tokens[0]] = map(float, tokens[1:])
    return data

# %%
from pprint import pprint as print
from gensim.models.fasttext import FastText
from gensim.test.utils import datapath

# Set file names for train and test data
corpus_file = datapath('lee_background.cor')

model = FastText()

# build the vocabulary
model.build_vocab(corpus_file=corpus_file)

# train the model
model.train(
    corpus_file=corpus_file, epochs=model.epochs,
    total_examples=model.corpus_count, total_words=model.corpus_total_words,
)

print(model)
# Out:
# <gensim.models.fasttext.FastText object at 0x0000014A3C4F5880>

# %%
df3 = calculate_heat_matrix_for_cosine_distance(df_m3, df_m3)
df3

# %%
showing_in_heamap(df3)

# %%
model["apple"]

# %% [markdown]
# ### To Do:
#
#
# #### Report:
# 1. Introduction
# 2. (Data Preprocessing)
#     i. how I collected data from linkedin
#     ii. cleaning data
# 3. Methodology
#     i. cosine similarity + bag of words
#     ii. gloVe word embedding + cosine similarity
#     iii. Visualization (heat map) libgen
# 4. Conclusion

# %%
## Word2Vec

import gensim.downloader as api
wv = api.load('word2vec-google-news-300')
# Out:
# [=-------------------------------------------------] 3.4% 56.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==------------------------------------------------] 5.6% 93.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===-----------------------------------------------] 7.6% 126.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [====----------------------------------------------] 9.8% 163.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=====---------------------------------------------] 12.0% 199.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=======-------------------------------------------] 14.1% 234.1/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [========------------------------------------------] 16.3% 271.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=========-----------------------------------------] 18.5% 307.7/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==========----------------------------------------] 20.5% 340.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===========---------------------------------------] 22.5% 374.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [============--------------------------------------] 24.6% 409.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=============-------------------------------------] 26.6% 441.6/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==============------------------------------------] 28.6% 475.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===============-----------------------------------] 30.5% 508.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [================----------------------------------] 32.5% 540.8/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=================---------------------------------] 34.7% 576.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==================--------------------------------] 36.7% 610.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===================-------------------------------] 38.8% 645.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [====================------------------------------] 41.0% 681.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=====================-----------------------------] 43.0% 715.4/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [======================----------------------------] 45.1% 750.7/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=======================---------------------------] 47.2% 784.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [========================--------------------------] 49.1% 815.8/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=========================-------------------------] 51.2% 850.8/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==========================------------------------] 54.0% 897.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===========================-----------------------] 55.9% 929.6/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=============================---------------------] 58.0% 965.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==============================--------------------] 60.2% 1000.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===============================-------------------] 62.1% 1031.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===============================-------------------] 63.9% 1063.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=================================-----------------] 66.5% 1105.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==================================----------------] 68.4% 1136.9/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===================================---------------] 70.3% 1169.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [====================================--------------] 72.1% 1199.5/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=====================================-------------] 74.3% 1234.7/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [======================================------------] 76.3% 1268.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=======================================-----------] 78.3% 1302.2/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [========================================----------] 80.4% 1336.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=========================================---------] 82.4% 1370.6/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==========================================--------] 84.9% 1411.1/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===========================================-------] 86.8% 1442.7/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [============================================------] 88.9% 1478.1/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [=============================================-----] 91.2% 1515.7/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==============================================----] 93.4% 1552.3/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [===============================================---] 95.5% 1588.8/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [================================================--] 98.0% 1629.0/1662.8MB downloaded
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
# [==================================================] 100.0% 1662.8/1662.8MB downloaded

# %%
vec_king = wv['king']

# %%
model = wv

# %%
df3 = calculate_heat_matrix_for_cosine_distance(df_m3,df_m3)
df3
# Out:
# Name                         Justin Lee  Zhi Yan (Ian) Leong [龙智彦] 😎  \
# Name
# Justin Lee                       100.00                        88.61
# Zhi Yan (Ian) Leong [龙智彦] 😎       88.61                       100.00
# Noah Cook                         86.37                        77.91
# Daniel Ramsey                     74.89                        79.41
# Jia Guo                           82.87                        69.29
# Mokshith Voodarla                 80.62                        75.93
# Xianyi “Sen” Xiong                80.08                        79.81
# Daniela Beck                      89.90                        83.32
# Stavros Anastasiou                80.78                        86.65
# Victoria Johnson                  82.48                        72.07
# M. Razlan Dhamir Hamdan           84.47                        87.86
# Dzuleira Abu Bakar                59.59                        60.56
# Andrew Nguyen                    79.04                        70.41
#
# Name                         Noah Cook  Daniel Ramsey  Jia Guo  \
# Name
# Justin Lee                       86.37          74.89    82.87
# Zhi Yan (Ian) Leong [龙智彦] 😎      77.91          79.41    69.29
# Noah Cook                       100.00          72.09    83.17
# Daniel Ramsey                    72.09         100.00    57.86
# Jia Guo                          83.17          57.86   100.00
# Mokshith Voodarla                76.93          66.68    76.22
# Xianyi “Sen” Xiong               65.65          71.00    62.68
# Daniela Beck                     84.89          73.52    82.55
# Stavros Anastasiou               72.52          78.00    61.07
# Victoria Johnson                 88.62          65.10    83.53
# M. Razlan Dhamir Hamdan          71.32          71.96    66.02
# Dzuleira Abu Bakar               51.09          54.36    51.47
# Andrew Nguyen                   77.08          59.38    91.37
#
# Name                         Mokshith Voodarla  Xianyi “Sen” Xiong  \
# Name
# Justin Lee                               80.62               80.08
# Zhi Yan (Ian) Leong [龙智彦] 😎              75.93               79.81
# Noah Cook                                76.93               65.65
# Daniel Ramsey                            66.68               71.00
# Jia Guo                                  76.22               62.68
# Mokshith Voodarla                       100.00               64.86
# Xianyi “Sen” Xiong                       64.86              100.00
# Daniela Beck                             72.77               79.87
# Stavros Anastasiou                       66.23               78.12
# Victoria Johnson                         69.05               61.39
# M. Razlan Dhamir Hamdan                  68.26               83.44
# Dzuleira Abu Bakar                       44.30               65.19
# Andrew Nguyen                           74.12               63.66
#
# Name                         Daniela Beck  Stavros Anastasiou  \
# Name
# Justin Lee                          89.90               80.78
# Zhi Yan (Ian) Leong [龙智彦] 😎         83.32               86.65
# Noah Cook                           84.89               72.52
# Daniel Ramsey                       73.52               78.00
# Jia Guo                             82.55               61.07
# Mokshith Voodarla                   72.77               66.23
# Xianyi “Sen” Xiong                  79.87               78.12
# Daniela Beck                       100.00               81.44
# Stavros Anastasiou                  81.44              100.00
# Victoria Johnson                    83.29               67.58
# M. Razlan Dhamir Hamdan             83.17               79.57
# Dzuleira Abu Bakar                  67.35               59.61
# Andrew Nguyen                      80.87               61.54
#
# Name                         Victoria Johnson  M. Razlan Dhamir Hamdan  \
# Name
# Justin Lee                              82.48                    84.47
# Zhi Yan (Ian) Leong [龙智彦] 😎             72.07                    87.86
# Noah Cook                               88.62                    71.32
# Daniel Ramsey                           65.10                    71.96
# Jia Guo                                 83.53                    66.02
# Mokshith Voodarla                       69.05                    68.26
# Xianyi “Sen” Xiong                      61.39                    83.44
# Daniela Beck                            83.29                    83.17
# Stavros Anastasiou                      67.58                    79.57
# Victoria Johnson                       100.00                    70.76
# M. Razlan Dhamir Hamdan                 70.76                   100.00
# Dzuleira Abu Bakar                      51.05                    73.55
# Andrew Nguyen                          76.94                    67.53
#
# Name                         Dzuleira Abu Bakar  Andrew Nguyen 
# Name
# Justin Lee                                59.59            79.04
# Zhi Yan (Ian) Leong [龙智彦] 😎               60.56            70.41
# Noah Cook                                 51.09            77.08
# Daniel Ramsey                             54.36            59.38
# Jia Guo                                   51.47            91.37
# Mokshith Voodarla                         44.30            74.12
# Xianyi “Sen” Xiong                        65.19            63.66
# Daniela Beck                              67.35            80.87
# Stavros Anastasiou                        59.61            61.54
# Victoria Johnson                          51.05            76.94
# M. Razlan Dhamir Hamdan                   73.55            67.53
# Dzuleira Abu Bakar                       100.00            54.33
# Andrew Nguyen                            54.33           100.00

# %%
showing_in_heamap(df3)
# Out:
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 40857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 26234 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 24422 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 63743 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 40857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 26234 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 24422 missing from current font.
#   font.set_text(s, 0, flags=flags)
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 63743 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:xlabel='Name', ylabel='Name'>

# %%
from gensim.models.keyedvectors import KeyedVectors
word_vect = KeyedVectors.load_word2vec_format("SO_vectors_200.bin", binary=True)

# %%
words=['virus','java','mysql']
for w in words:
    try:
        print(word_vect.most_similar(w))
    except KeyError as e:
            print(e)
# Out:
# [('malware', 0.8455425500869751),
#  ('viruses', 0.8440008759498596),
#  ('antivirus', 0.8379444479942322),
#  ('anti-virus', 0.8235735893249512),
#  ('spyware', 0.7659314870834351),
#  ('mcafee', 0.754204511642456),
#  ('malwarebytes', 0.7523448467254639),
#  ('avast', 0.7465472221374512),
#  ('avira', 0.7376064658164978),
#  ('anti-malware', 0.7363340854644775)]
# [('jave', 0.7305740118026733),
#  ('j2se', 0.6334485411643982),
#  ('javase', 0.6294389367103577),
#  ('scala', 0.6201648116111755),
#  ('non-java', 0.61116623878479),
#  ('javas', 0.6073752045631409),
#  ('-java', 0.5853540897369385),
#  ('jav', 0.5707030296325684),
#  ('jdk', 0.5517216920852661),
#  ('java5', 0.5513849258422852)]
# [('postgresql', 0.7997364401817322),
#  ('postgres', 0.7909045219421387),
#  ('mssql', 0.7834541201591492),
#  ('mariadb', 0.7827132344245911),
#  ('msql', 0.7762644290924072),
#  ('postgressql', 0.7286335229873657),
#  ('mysql/mariadb', 0.7264211177825928),
#  ('postresql', 0.7253730297088623),
#  ('postgre', 0.7069053053855896),
#  ('pgsql', 0.7036819458007812)]

# %%
print(word_vect.doesnt_match("java c++ python bash".split()))
# Out:
# 'bash'
# c:\users\justi\documents\code\summer-research\research-venv\lib\site-packages\gensim\models\keyedvectors.py:877: FutureWarning: arrays to stack must be passed as a "sequence" type such as list or tuple. Support for non-sequence iterables such as generators is deprecated as of NumPy 1.16 and will raise an error in the future.
#   vectors = vstack(self.word_vec(word, use_norm=True) for word in used_words).astype(REAL)

# %%
model = word_vect

# %%
df3 = calculate_heat_matrix_for_cosine_distance(df_m3,df_m3)
df3
# Out:
# Name                         Justin Lee  Zhi Yan (Ian) Leong [龙智彦] 😎  \
# Name
# Justin Lee                       100.00                        90.74
# Zhi Yan (Ian) Leong [龙智彦] 😎       90.74                       100.00
# Noah Cook                         87.86                        84.54
# Daniel Ramsey                     86.28                        84.38
# Jia Guo                           81.13                        75.58
# Mokshith Voodarla                 86.09                        81.72
# Xianyi “Sen” Xiong                85.87                        85.71
# Daniela Beck                      85.24                        84.29
# Stavros Anastasiou                87.21                        86.71
# Victoria Johnson                  79.75                        74.35
# M. Razlan Dhamir Hamdan           89.64                        94.37
# Dzuleira Abu Bakar                73.79                        77.49
# Andrew Nguyen                    75.66                        76.20
#
# Name                         Noah Cook  Daniel Ramsey  Jia Guo  \
# Name
# Justin Lee                       87.86          86.28    81.13
# Zhi Yan (Ian) Leong [龙智彦] 😎      84.54          84.38    75.58
# Noah Cook                       100.00          80.26    82.64
# Daniel Ramsey                    80.26         100.00    71.25
# Jia Guo                          82.64          71.25   100.00
# Mokshith Voodarla                81.83          82.64    81.34
# Xianyi “Sen” Xiong               75.97          77.94    63.59
# Daniela Beck                     85.21          75.37    73.48
# Stavros Anastasiou               79.16          85.79    62.17
# Victoria Johnson                 87.49          68.68    80.39
# M. Razlan Dhamir Hamdan          81.38          79.42    76.65
# Dzuleira Abu Bakar               67.39          72.98    54.98
# Andrew Nguyen                   75.19          69.26    83.06
#
# Name                         Mokshith Voodarla  Xianyi “Sen” Xiong  \
# Name
# Justin Lee                               86.09               85.87
# Zhi Yan (Ian) Leong [龙智彦] 😎              81.72               85.71
# Noah Cook                                81.83               75.97
# Daniel Ramsey                            82.64               77.94
# Jia Guo                                  81.34               63.59
# Mokshith Voodarla                       100.00               69.90
# Xianyi “Sen” Xiong                       69.90              100.00
# Daniela Beck                             72.28               85.13
# Stavros Anastasiou                       74.61               86.82
# Victoria Johnson                         70.50               62.27
# M. Razlan Dhamir Hamdan                  76.85               86.14
# Dzuleira Abu Bakar                       58.00               80.06
# Andrew Nguyen                           75.33               65.04
#
# Name                         Daniela Beck  Stavros Anastasiou  \
# Name
# Justin Lee                          85.24               87.21
# Zhi Yan (Ian) Leong [龙智彦] 😎         84.29               86.71
# Noah Cook                           85.21               79.16
# Daniel Ramsey                       75.37               85.79
# Jia Guo                             73.48               62.17
# Mokshith Voodarla                   72.28               74.61
# Xianyi “Sen” Xiong                  85.13               86.82
# Daniela Beck                       100.00               83.27
# Stavros Anastasiou                  83.27              100.00
# Victoria Johnson                    81.20               65.62
# M. Razlan Dhamir Hamdan             84.17               85.63
# Dzuleira Abu Bakar                  76.71               78.25
# Andrew Nguyen                      75.05               66.19
#
# Name                         Victoria Johnson  M. Razlan Dhamir Hamdan  \
# Name
# Justin Lee                              79.75                    89.64
# Zhi Yan (Ian) Leong [龙智彦] 😎             74.35                    94.37
# Noah Cook                               87.49                    81.38
# Daniel Ramsey                           68.68                    79.42
# Jia Guo                                 80.39                    76.65
# Mokshith Voodarla                       70.50                    76.85
# Xianyi “Sen” Xiong                      62.27                    86.14
# Daniela Beck                            81.20                    84.17
# Stavros Anastasiou                      65.62                    85.63
# Victoria Johnson                       100.00                    74.25
# M. Razlan Dhamir Hamdan                 74.25                   100.00
# Dzuleira Abu Bakar                      61.33                    78.47
# Andrew Nguyen                          75.05                    76.25
#
# Name                         Dzuleira Abu Bakar  Andrew Nguyen 
# Name
# Justin Lee                                73.79            75.66
# Zhi Yan (Ian) Leong [龙智彦] 😎               77.49            76.20
# Noah Cook                                 67.39            75.19
# Daniel Ramsey                             72.98            69.26
# Jia Guo                                   54.98            83.06
# Mokshith Voodarla                         58.00            75.33
# Xianyi “Sen” Xiong                        80.06            65.04
# Daniela Beck                              76.71            75.05
# Stavros Anastasiou                        78.25            66.19
# Victoria Johnson                          61.33            75.05
# M. Razlan Dhamir Hamdan                   78.47            76.25
# Dzuleira Abu Bakar                       100.00            57.59
# Andrew Nguyen                            57.59           100.00
